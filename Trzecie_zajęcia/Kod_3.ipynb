# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("okienka").getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://cca2dda07ef3:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.0-preview2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>okienka</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
czujnik_temperatury = ((12.5, "2019-01-02 12:00:00"),
(17.6, "2019-01-02 12:00:20"),
(14.6,  "2019-01-02 12:00:30"),
(22.9,  "2019-01-02 12:01:15"),
(17.4,  "2019-01-02 12:01:30"),
(25.8,  "2019-01-02 12:03:25"),
(27.1,  "2019-01-02 12:02:40"),
)

# %%
from pyspark.sql.functions import to_timestamp
from pyspark.sql.types import StructType, StructField, StringType, DoubleType

schema = StructType([
    StructField("temperatura", DoubleType(), True),
    StructField("czas", StringType(), True),
])

# %%
df = (spark.createDataFrame(czujnik_temperatury, schema=schema)
      .withColumn("czas", to_timestamp("czas")))

df.printSchema()
# Out:
# root
#  |-- temperatura: double (nullable = true)
#  |-- czas: timestamp (nullable = true)

# %%
df.show(3)
# Out:
# +-----------+-------------------+
# |temperatura|               czas|
# +-----------+-------------------+
# |       12.5|2019-01-02 12:00:00|
# |       17.6|2019-01-02 12:00:20|
# |       14.6|2019-01-02 12:00:30|
# +-----------+-------------------+
# only showing top 3 rows

# %%
df.createOrReplaceTempView("df")

# %%
spark.sql("select czas, temperatura from df where temperatura > 21").show(5)
# Out:
# +-------------------+-----------+
# |               czas|temperatura|
# +-------------------+-----------+
# |2019-01-02 12:01:15|       22.9|
# |2019-01-02 12:03:25|       25.8|
# |2019-01-02 12:02:40|       27.1|
# +-------------------+-----------+

# %%
# Thumbling window

import pyspark.sql.functions as F

df2 = df.groupBy(F.window("czas","30 seconds")).count()
df2.show(truncate=False)
# Out:
# +------------------------------------------+-----+
# |window                                    |count|
# +------------------------------------------+-----+
# |{2019-01-02 12:00:00, 2019-01-02 12:00:30}|2    |
# |{2019-01-02 12:00:30, 2019-01-02 12:01:00}|1    |
# |{2019-01-02 12:01:00, 2019-01-02 12:01:30}|1    |
# |{2019-01-02 12:01:30, 2019-01-02 12:02:00}|1    |
# |{2019-01-02 12:03:00, 2019-01-02 12:03:30}|1    |
# |{2019-01-02 12:02:30, 2019-01-02 12:03:00}|1    |
# +------------------------------------------+-----+

# %%
df2.printSchema()
# Out:
# root
#  |-- window: struct (nullable = false)
#  |    |-- start: timestamp (nullable = true)
#  |    |-- end: timestamp (nullable = true)
#  |-- count: long (nullable = false)

# %%
spark.stop()

# %% [markdown]
# Output Modes

# %%
# %%file streamrate.py
## uruchom przez spark-submit streamrate.py

from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("StreamingDemo").getOrCreate()
spark.sparkContext.setLogLevel("WARN")

df = (spark.readStream
      .format("rate")
      .option("rowsPerSecond", 1)
      .load()
)


query = (df.writeStream 
    .format("console") 
    .outputMode("append") 
    .option("truncate", False) 
    .start()
) 

query.awaitTermination()
# Out:
# Overwriting streamrate.py

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("StreamingDemo").getOrCreate()
spark.sparkContext.setLogLevel("WARN")

def process_batch(df, batch_id, tstop=5):
    print(f"Batch ID: {batch_id}")
    df.show(truncate=False)
    if batch_id == tstop:
        df.stop()


df = (spark.readStream
      .format("rate")
      .option("rowsPerSecond", 1)
      .load()
)

query = (df.writeStream 
    .format("console") 
    .outputMode("append")
    .foreachBatch(process_batch)
    .option("truncate", False) 
    .start()
)
# Out:
# Batch ID: 0
# +---------+-----+
# |timestamp|value|
# +---------+-----+
# +---------+-----+
#
# Batch ID: 0
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 0
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 1
# +-----------------------+-----+
# |timestamp              |value|
# +-----------------------+-----+
# |2026-04-25 14:06:29.177|0    |
# +-----------------------+-----+
#
# Batch ID: 1
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:06:29.316|22.658802368794632|
# +-----------------------+------------------+
#
# Batch ID: 1
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 2
# +-----------------------+-----+
# |timestamp              |value|
# +-----------------------+-----+
# |2026-04-25 14:06:30.177|1    |
# +-----------------------+-----+
#
# Batch ID: 2
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:06:30.316|28.53118293303074|
# +-----------------------+-----------------+
#
# Batch ID: 2
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:06:30.562|26.435810184450222|
# +-----------------------+------------------+
#
# Batch ID: 3
# +-----------------------+-----+
# |timestamp              |value|
# +-----------------------+-----+
# |2026-04-25 14:06:31.177|2    |
# +-----------------------+-----+
#
# Batch ID: 3
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:06:31.316|29.729813690951026|
# +-----------------------+------------------+
#
# Batch ID: 3
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:06:31.562|27.270929522620246|
# +-----------------------+------------------+
#
# Batch ID: 4
# +-----------------------+-----+
# |timestamp              |value|
# +-----------------------+-----+
# |2026-04-25 14:06:32.177|3    |
# +-----------------------+-----+
#
# Batch ID: 4
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:06:32.316|28.299759609295343|
# +-----------------------+------------------+
#
# Batch ID: 4
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 5
# +-----------------------+-----+
# |timestamp              |value|
# +-----------------------+-----+
# |2026-04-25 14:06:33.177|4    |
# +-----------------------+-----+
#
# Batch ID: 5
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:06:33.316|23.984447248490312|
# +-----------------------+------------------+
#
# Batch ID: 5
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 6
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:06:34.562|28.549356118849474|
# +-----------------------+------------------+
#
# Batch ID: 7
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 8
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:06:36.562|27.67324991593872|
# +-----------------------+-----------------+
#
# Batch ID: 9
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 10
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 11
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 12
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 13
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 14
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:06:42.562|26.91321774078971|
# +-----------------------+-----------------+
#
# Batch ID: 15
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 16
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 17
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:06:45.562|26.939450309071628|
# +-----------------------+------------------+
#
# Batch ID: 18
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 19
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:06:47.562|26.600439421631222|
# +-----------------------+------------------+
#
# Batch ID: 20
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 21
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:06:49.562|28.272907419070147|
# +-----------------------+------------------+
#
# Batch ID: 22
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 23
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 24
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 25
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:06:53.562|28.651413906665855|
# +-----------------------+------------------+
#
# Batch ID: 26
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:06:54.562|27.007302789215366|
# +-----------------------+------------------+
#
# Batch ID: 27
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:06:55.562|29.679624786442847|
# +-----------------------+------------------+
#
# Batch ID: 28
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:06:56.562|28.835098621796227|
# +-----------------------+------------------+
#
# Batch ID: 29
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:06:57.562|29.752735726430664|
# +-----------------------+------------------+
#
# Batch ID: 30
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 31
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:06:59.562|27.034517431428213|
# +-----------------------+------------------+
#
# Batch ID: 32
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 33
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 34
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 35
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 36
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 37
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 38
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:07:06.562|29.44678116843859|
# +-----------------------+-----------------+
#
# Batch ID: 39
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:07:07.562|26.55461689236619|
# +-----------------------+-----------------+
#
# Batch ID: 40
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:07:08.562|26.971332430917236|
# +-----------------------+------------------+
#
# Batch ID: 41
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 42
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:07:10.562|26.254987397983665|
# +-----------------------+------------------+
#
# Batch ID: 43
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 44
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:07:12.562|29.975032666911325|
# +-----------------------+------------------+
#
# Batch ID: 45
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:07:13.562|26.379389131108137|
# +-----------------------+------------------+
#
# Batch ID: 46
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:07:14.562|29.371226438785424|
# +-----------------------+------------------+
#
# Batch ID: 47
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 48
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 49
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:07:17.562|29.008787017551285|
# +-----------------------+------------------+
#
# Batch ID: 50
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 51
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:07:19.562|28.101174242617933|
# +-----------------------+------------------+
#
# Batch ID: 52
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:07:20.562|28.47823568079764|
# +-----------------------+-----------------+
#
# Batch ID: 53
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 54
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 55
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 56
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 57
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 58
# +-----------------------+----------------+
# |czas                   |temperatura     |
# +-----------------------+----------------+
# |2026-04-25 14:07:26.562|26.5891786739063|
# +-----------------------+----------------+
#
# Batch ID: 59
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:07:27.562|27.85633137901665|
# +-----------------------+-----------------+
#
# Batch ID: 60
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 61
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:07:29.562|26.510347297225703|
# +-----------------------+------------------+
#
# Batch ID: 62
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 63
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:07:31.562|29.060411397406064|
# +-----------------------+------------------+
#
# Batch ID: 64
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 65
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 66
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 67
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:07:35.562|29.325825468089302|
# +-----------------------+------------------+
#
# Batch ID: 68
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:07:36.562|26.34419815465134|
# +-----------------------+-----------------+
#
# Batch ID: 69
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 70
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:07:38.562|27.28109005982369|
# +-----------------------+-----------------+
#
# Batch ID: 71
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 72
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:07:40.562|26.390526643709357|
# +-----------------------+------------------+
#
# Batch ID: 73
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 74
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:07:42.562|26.954681600785143|
# +-----------------------+------------------+
#
# Batch ID: 75
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 76
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 77
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 78
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 79
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 80
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:07:48.562|27.721598163712937|
# +-----------------------+------------------+
#
# Batch ID: 81
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 82
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 83
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 84
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 85
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 86
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 87
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 88
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 89
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:07:57.562|29.299628590304415|
# +-----------------------+------------------+
#
# Batch ID: 90
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:07:58.562|26.73413746391266|
# +-----------------------+-----------------+
#
# Batch ID: 91
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 92
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:08:00.562|29.809871579132796|
# +-----------------------+------------------+
#
# Batch ID: 93
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 94
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 95
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 96
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 97
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 98
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 99
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 100
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 101
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 102
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:08:10.562|26.05848328786378|
# +-----------------------+-----------------+
#
# Batch ID: 103
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:08:11.562|26.299515766782317|
# +-----------------------+------------------+
#
# Batch ID: 104
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 105
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:08:13.562|27.067876862198787|
# +-----------------------+------------------+
#
# Batch ID: 106
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 107
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:08:15.562|28.35081715093874|
# +-----------------------+-----------------+
#
# Batch ID: 108
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 109
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:08:17.562|28.414614471103853|
# +-----------------------+------------------+
#
# Batch ID: 110
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 111
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 112
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 113
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 114
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:08:22.562|27.197174249445506|
# +-----------------------+------------------+
#
# Batch ID: 115
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:08:23.562|26.28329254028993|
# +-----------------------+-----------------+
#
# Batch ID: 116
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 117
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:08:25.562|27.995362417658637|
# +-----------------------+------------------+
#
# Batch ID: 118
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 119
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 120
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:08:28.562|27.75654482920513|
# +-----------------------+-----------------+
#
# Batch ID: 121
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 122
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 123
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:08:31.562|26.200409399510683|
# +-----------------------+------------------+
#
# Batch ID: 124
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 125
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 126
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 127
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 128
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 129
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:08:37.562|26.670504388478722|
# +-----------------------+------------------+
#
# Batch ID: 130
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 131
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 132
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:08:40.562|27.160251760610894|
# +-----------------------+------------------+
#
# Batch ID: 133
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 134
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 135
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:08:43.562|27.503400384494178|
# +-----------------------+------------------+
#
# Batch ID: 136
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:08:44.562|28.45101658893763|
# +-----------------------+-----------------+
#
# Batch ID: 137
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 138
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:08:46.562|29.855564462925827|
# +-----------------------+------------------+
#
# Batch ID: 139
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 140
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:08:48.562|29.915994683296272|
# +-----------------------+------------------+
#
# Batch ID: 141
# +-----------------------+---------------+
# |czas                   |temperatura    |
# +-----------------------+---------------+
# |2026-04-25 14:08:49.562|27.840903922564|
# +-----------------------+---------------+
#
# Batch ID: 142
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:08:50.562|29.86712779120863|
# +-----------------------+-----------------+
#
# Batch ID: 143
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 144
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 145
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:08:53.562|27.164458287349145|
# +-----------------------+------------------+
#
# Batch ID: 146
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 147
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 148
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:08:56.562|27.046830943350876|
# +-----------------------+------------------+
#
# Batch ID: 149
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 150
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:08:58.562|27.08283938076452|
# +-----------------------+-----------------+
#
# Batch ID: 151
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 152
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 153
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 154
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:09:02.562|29.399215379409643|
# +-----------------------+------------------+
#
# Batch ID: 155
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 156
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 157
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 158
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:09:06.562|27.270021463837704|
# +-----------------------+------------------+
#
# Batch ID: 159
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:09:07.562|29.498529688937044|
# +-----------------------+------------------+
#
# Batch ID: 160
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 161
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:09:09.562|27.696217265769683|
# +-----------------------+------------------+
#
# Batch ID: 162
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 163
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:09:11.562|27.757393631832386|
# +-----------------------+------------------+
#
# Batch ID: 164
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 165
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 166
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 167
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 168
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 169
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 170
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:09:18.562|29.320719450564532|
# +-----------------------+------------------+
#
# Batch ID: 171
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 172
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:09:20.562|29.14123233786794|
# +-----------------------+-----------------+
#
# Batch ID: 173
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 174
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 175
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 176
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 177
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 178
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:09:26.562|26.01047214904257|
# +-----------------------+-----------------+
#
# Batch ID: 179
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 180
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:09:28.562|29.456676760110124|
# +-----------------------+------------------+
#
# Batch ID: 181
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:09:29.562|28.83290084449035|
# +-----------------------+-----------------+
#
# Batch ID: 182
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:09:30.562|28.98456694458664|
# +-----------------------+-----------------+
#
# Batch ID: 183
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:09:31.562|27.47875164409092|
# +-----------------------+-----------------+
#
# Batch ID: 184
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:09:32.562|26.33435208317708|
# +-----------------------+-----------------+
#
# Batch ID: 185
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 186
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 187
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 188
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:09:36.562|27.109533463049747|
# +-----------------------+------------------+
#
# Batch ID: 189
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:09:37.562|26.064135271694866|
# +-----------------------+------------------+
#
# Batch ID: 190
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:09:38.562|28.422109815309483|
# +-----------------------+------------------+
#
# Batch ID: 191
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:09:39.562|26.007812248249543|
# +-----------------------+------------------+
#
# Batch ID: 192
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:09:40.562|28.863653811308893|
# +-----------------------+------------------+
#
# Batch ID: 193
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:09:41.562|27.005639302486586|
# +-----------------------+------------------+
#
# Batch ID: 194
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:09:42.562|27.206830513642423|
# +-----------------------+------------------+
#
# Batch ID: 195
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 196
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 197
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:09:45.562|28.86579948285653|
# +-----------------------+-----------------+
#
# Batch ID: 198
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 199
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 200
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:09:48.562|29.52100810510348|
# +-----------------------+-----------------+
#
# Batch ID: 201
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:09:49.562|29.81289199366276|
# +-----------------------+-----------------+
#
# Batch ID: 202
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:09:50.562|28.181340069615203|
# +-----------------------+------------------+
#
# Batch ID: 203
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 204
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 205
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:09:53.562|28.663401466459767|
# +-----------------------+------------------+
#
# Batch ID: 206
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:09:54.562|26.350758601743728|
# +-----------------------+------------------+
#
# Batch ID: 207
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:09:55.562|29.88878328254441|
# +-----------------------+-----------------+
#
# Batch ID: 208
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:09:56.562|26.513412648335798|
# +-----------------------+------------------+
#
# Batch ID: 209
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 210
# +-----------------------+---------------+
# |czas                   |temperatura    |
# +-----------------------+---------------+
# |2026-04-25 14:09:58.562|28.196761803308|
# +-----------------------+---------------+
#
# Batch ID: 211
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 212
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:10:00.562|27.182959409677956|
# +-----------------------+------------------+
#
# Batch ID: 213
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 214
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 215
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 216
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 217
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:10:05.562|26.515813051510854|
# +-----------------------+------------------+
#
# Batch ID: 218
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 219
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 220
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 221
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:10:09.562|28.97674088954529|
# +-----------------------+-----------------+
#
# Batch ID: 222
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 223
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 224
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:10:12.562|29.556222681603025|
# +-----------------------+------------------+
#
# Batch ID: 225
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:10:13.562|29.31814630173411|
# +-----------------------+-----------------+
#
# Batch ID: 226
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:10:14.562|26.690986192190902|
# +-----------------------+------------------+
#
# Batch ID: 227
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 228
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:10:16.562|26.486005755800406|
# +-----------------------+------------------+
#
# Batch ID: 229
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:10:17.562|26.062425845461366|
# +-----------------------+------------------+
#
# Batch ID: 230
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 231
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 232
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 233
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 234
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 235
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:10:23.562|27.371769237613748|
# +-----------------------+------------------+
#
# Batch ID: 236
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:10:24.562|29.320774115520763|
# +-----------------------+------------------+
#
# Batch ID: 237
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:10:25.562|29.88696217936712|
# +-----------------------+-----------------+
#
# Batch ID: 238
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:10:26.562|27.397673816144348|
# +-----------------------+------------------+
#
# Batch ID: 239
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 240
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 241
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 242
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 243
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 244
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:10:32.562|28.07118244945432|
# +-----------------------+-----------------+
#
# Batch ID: 245
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:10:33.562|28.475480078634114|
# +-----------------------+------------------+
#
# Batch ID: 246
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:10:34.562|27.235471868341705|
# +-----------------------+------------------+
#
# Batch ID: 247
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 248
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 249
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 250
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:10:38.562|26.50127478019182|
# +-----------------------+-----------------+
#
# Batch ID: 251
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 252
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:10:40.562|27.251528510358668|
# +-----------------------+------------------+
#
# Batch ID: 253
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 254
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 255
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:10:43.562|28.37150715398106|
# +-----------------------+-----------------+
#
# Batch ID: 256
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:10:44.562|26.17079449886581|
# +-----------------------+-----------------+
#
# Batch ID: 257
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:10:45.562|26.943822878219272|
# +-----------------------+------------------+
#
# Batch ID: 258
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 259
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:10:47.562|28.756812341399126|
# +-----------------------+------------------+
#
# Batch ID: 260
# +-----------------------+----------------+
# |czas                   |temperatura     |
# +-----------------------+----------------+
# |2026-04-25 14:10:48.562|26.8233681333839|
# +-----------------------+----------------+
#
# Batch ID: 261
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 262
# +-----------------------+---------------+
# |czas                   |temperatura    |
# +-----------------------+---------------+
# |2026-04-25 14:10:50.562|29.701544285641|
# +-----------------------+---------------+
#
# Batch ID: 263
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 264
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:10:52.562|27.857002548810314|
# +-----------------------+------------------+
#
# Batch ID: 265
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:10:53.562|27.57947334685487|
# +-----------------------+-----------------+
#
# Batch ID: 266
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:10:54.562|26.555871840205207|
# +-----------------------+------------------+
#
# Batch ID: 267
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:10:55.562|26.89462892486633|
# +-----------------------+-----------------+
#
# Batch ID: 268
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 269
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:10:57.562|26.39020736663293|
# +-----------------------+-----------------+
#
# Batch ID: 270
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:10:58.562|27.41608520426329|
# +-----------------------+-----------------+
#
# Batch ID: 271
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:10:59.562|28.18649911777442|
# +-----------------------+-----------------+
#
# Batch ID: 272
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 273
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 274
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:11:02.562|28.496004223875147|
# +-----------------------+------------------+
#
# Batch ID: 275
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 276
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 277
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 278
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:11:06.562|27.859459643823772|
# +-----------------------+------------------+
#
# Batch ID: 279
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:11:07.562|26.508409977459955|
# +-----------------------+------------------+
#
# Batch ID: 280
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 281
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 282
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:11:10.562|26.218221274824614|
# +-----------------------+------------------+
#
# Batch ID: 283
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 284
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 285
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 286
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:11:14.562|29.69677582958397|
# +-----------------------+-----------------+
#
# Batch ID: 287
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:11:15.562|29.694140516140404|
# +-----------------------+------------------+
#
# Batch ID: 288
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 289
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 290
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:11:18.562|28.839050426954625|
# +-----------------------+------------------+
#
# Batch ID: 291
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 292
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 293
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 294
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 295
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:11:23.562|29.818661979124727|
# +-----------------------+------------------+
#
# Batch ID: 296
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:11:24.562|28.192305205653362|
# +-----------------------+------------------+
#
# Batch ID: 297
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 298
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# ...
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:15:51.562|29.199589679438347|
# +-----------------------+------------------+
#
# Batch ID: 564
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:15:52.562|28.43495899158932|
# +-----------------------+-----------------+
#
# Batch ID: 565
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:15:53.562|26.486265241474733|
# +-----------------------+------------------+
#
# Batch ID: 566
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 567
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 568
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:15:56.562|29.62193963766697|
# +-----------------------+-----------------+
#
# Batch ID: 569
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 570
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 571
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:15:59.562|27.12399851020637|
# +-----------------------+-----------------+
#
# Batch ID: 572
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 573
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 574
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 575
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 576
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 577
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:16:05.562|27.444174041043436|
# +-----------------------+------------------+
#
# Batch ID: 578
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 579
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:16:07.562|29.56084556920961|
# +-----------------------+-----------------+
#
# Batch ID: 580
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 581
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 582
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 583
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:16:11.562|27.463740246578702|
# +-----------------------+------------------+
#
# Batch ID: 584
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:16:12.562|26.328717378888154|
# +-----------------------+------------------+
#
# Batch ID: 585
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 586
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 587
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14
# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("StreamingDemo").getOrCreate()
spark.sparkContext.setLogLevel("WARN")

def process_batch(df, batch_id, tstop=5):
    print(f"Batch ID: {batch_id}")
    df.show(truncate=False)
    if batch_id == tstop:
        df.stop()

from pyspark.sql.functions import col, expr

df = (spark.readStream
      .format("rate")
      .option("rowsPerSecond", 1)
      .load()
)

stream = (df.withColumn("czas", col("timestamp"))
        .withColumn("temperatura", expr("20 + rand() * 10"))
        .select("czas", "temperatura")
       )

query = (stream.writeStream 
    .format("console") 
    .outputMode("append")
    .foreachBatch(process_batch)
    .option("truncate", False) 
    .start()
)
# Out:
# Batch ID: 0
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 1
# +----------------------+-----------------+
# |czas                  |temperatura      |
# +----------------------+-----------------+
# |2026-04-25 14:18:07.66|28.01463492123149|
# +----------------------+-----------------+
#
# Batch ID: 2
# +----------------------+-----------------+
# |czas                  |temperatura      |
# +----------------------+-----------------+
# |2026-04-25 14:18:08.66|20.99168740162729|
# +----------------------+-----------------+
#
# Batch ID: 3
# +----------------------+------------------+
# |czas                  |temperatura       |
# +----------------------+------------------+
# |2026-04-25 14:18:09.66|21.234459272672293|
# +----------------------+------------------+
#
# Batch ID: 4
# +----------------------+------------------+
# |czas                  |temperatura       |
# +----------------------+------------------+
# |2026-04-25 14:18:10.66|24.579768434263233|
# +----------------------+------------------+
#
# Batch ID: 5
# +----------------------+------------------+
# |czas                  |temperatura       |
# +----------------------+------------------+
# |2026-04-25 14:18:11.66|23.493222732395665|
# +----------------------+------------------+

# %% [markdown]
# Transformacja bezstanowa

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("StreamingDemo").getOrCreate()
spark.sparkContext.setLogLevel("WARN")

def process_batch(df, batch_id, tstop=5):
    print(f"Batch ID: {batch_id}")
    df.show(truncate=False)
    if batch_id == tstop:
        df.show(truncate=False)


from pyspark.sql.functions import col, expr

df = (spark.readStream
      .format("rate")
      .option("rowsPerSecond", 1)
      .load()
)

stream = (df.withColumn("czas", col("timestamp"))
        .withColumn("temperatura", expr("20 + rand() * 10"))
        .select("czas", "temperatura")
       )

stream_filtered = stream.filter(col("temperatura") > 26)

query = (stream_filtered.writeStream 
    .format("console") 
    .outputMode("append")
    .foreachBatch(process_batch)
    .option("truncate", False) 
    .start()
)
query.awaitTermination()
# Out:
# Batch ID: 0
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 1
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 2
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 3
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 4
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 5
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:33:56.572|29.519148294392025|
# +-----------------------+------------------+
#
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:33:56.572|29.519148294392025|
# +-----------------------+------------------+
#
# Batch ID: 6
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 7
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:33:58.572|29.959099511054518|
# +-----------------------+------------------+
#
# Batch ID: 8
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:33:59.572|28.121816454815402|
# +-----------------------+------------------+
#
# Batch ID: 9
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:34:00.572|29.633391524903473|
# +-----------------------+------------------+
#
# Batch ID: 10
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 11
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 12
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 13
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 14
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 15
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 16
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 17
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:34:08.572|28.67091843352482|
# +-----------------------+-----------------+
#
# Batch ID: 18
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 19
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:34:10.572|28.53598238910937|
# +-----------------------+-----------------+
#
# Batch ID: 20
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:34:11.572|26.622090503958177|
# +-----------------------+------------------+
#
# Batch ID: 21
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:34:12.572|28.43137742348306|
# +-----------------------+-----------------+
#
# Batch ID: 22
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 23
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:34:14.572|27.036301993494444|
# +-----------------------+------------------+
#
# Batch ID: 24
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:34:15.572|29.526096641547085|
# +-----------------------+------------------+
#
# Batch ID: 25
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 98
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:35:29.572|26.070959870335482|
# +-----------------------+------------------+
#
# Batch ID: 99
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 100
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 101
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:35:32.572|27.67022092421556|
# +-----------------------+-----------------+
#
# Batch ID: 102
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:35:33.572|29.672239809339004|
# +-----------------------+------------------+
#
# Batch ID: 103
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:35:34.572|28.685600165100823|
# +-----------------------+------------------+
#
# Batch ID: 104
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 105
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:35:36.572|26.312761286663864|
# +-----------------------+------------------+
#
# Batch ID: 106
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:35:37.572|26.743604406549377|
# +-----------------------+------------------+
#
# Batch ID: 107
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 108
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 109
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 110
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:35:41.572|26.496198575577818|
# +-----------------------+------------------+
#
# Batch ID: 111
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 112
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:35:43.572|26.35816716770455|
# +-----------------------+-----------------+
#
# Batch ID: 113
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 114
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 115
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:35:46.572|28.391683206342996|
# +-----------------------+------------------+
#
# Batch ID: 116
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:35:47.572|27.799629224299768|
# +-----------------------+------------------+
#
# Batch ID: 117
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 118
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 119
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 120
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 121
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 122
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 123
# +-----------------------+------------------+
# |czas                   |temperatura       |
# +-----------------------+------------------+
# |2026-04-25 14:35:54.572|28.798787633327347|
# +-----------------------+------------------+
#
# Batch ID: 124
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+
#
# Batch ID: 125
# +-----------------------+-----------------+
# |czas                   |temperatura      |
# +-----------------------+-----------------+
# |2026-04-25 14:35:56.572|26.43316360029217|
# +-----------------------+-----------------+
#
# Batch ID: 126
# +----+-----------+
# |czas|temperatura|
# +----+-----------+
# +----+-----------+

# %% [markdown]
# Prosty model wykrywający anomalie

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, expr, when

spark = SparkSession.builder.appName("StreamingDemo").getOrCreate()
spark.sparkContext.setLogLevel("WARN")

def process_batch(df, batch_id, tstop=10):
    print(f"Batch ID: {batch_id}")
    df.show(truncate=False)
    if batch_id == tstop:
        df.stop()



df = (spark.readStream
      .format("rate")
      .option("rowsPerSecond", 1)
      .load()
)

stream = (df.withColumn("czas", col("timestamp"))
        .withColumn("temperatura", expr("20 + rand() * 10"))
        .select("czas", "temperatura")
       )

stream_anomaly = stream.withColumn(
    "anomaly",
    when(col("temperatura") > 29.5, "TAK").otherwise("NIE")
)

query = (stream_anomaly.writeStream 
    .format("console") 
    .outputMode("append")
    .foreachBatch(process_batch)
    .option("truncate", False) 
    .start()
)
# Out:
# Batch ID: 0
# +----+-----------+-------+
# |czas|temperatura|anomaly|
# +----+-----------+-------+
# +----+-----------+-------+
#
# Batch ID: 1
# +-----------------------+-----------------+-------+
# |czas                   |temperatura      |anomaly|
# +-----------------------+-----------------+-------+
# |2026-04-25 14:39:57.733|29.91606239709739|TAK    |
# +-----------------------+-----------------+-------+
#
# Batch ID: 2
# +-----------------------+------------------+-------+
# |czas                   |temperatura       |anomaly|
# +-----------------------+------------------+-------+
# |2026-04-25 14:39:58.733|28.597311043174553|NIE    |
# +-----------------------+------------------+-------+
#
# Batch ID: 3
# +-----------------------+------------------+-------+
# |czas                   |temperatura       |anomaly|
# +-----------------------+------------------+-------+
# |2026-04-25 14:39:59.733|21.850865521483676|NIE    |
# +-----------------------+------------------+-------+
#
# Batch ID: 4
# +-----------------------+----------------+-------+
# |czas                   |temperatura     |anomaly|
# +-----------------------+----------------+-------+
# |2026-04-25 14:40:00.733|25.4370516108638|NIE    |
# +-----------------------+----------------+-------+
#
# Batch ID: 5
# +-----------------------+-----------------+-------+
# |czas                   |temperatura      |anomaly|
# +-----------------------+-----------------+-------+
# |2026-04-25 14:40:01.733|22.59043962444775|NIE    |
# +-----------------------+-----------------+-------+
#
# Batch ID: 6
# +-----------------------+-----------------+-------+
# |czas                   |temperatura      |anomaly|
# +-----------------------+-----------------+-------+
# |2026-04-25 14:40:02.733|21.54199662569526|NIE    |
# +-----------------------+-----------------+-------+
#
# Batch ID: 7
# +-----------------------+------------------+-------+
# |czas                   |temperatura       |anomaly|
# +-----------------------+------------------+-------+
# |2026-04-25 14:40:03.733|24.641845937447595|NIE    |
# +-----------------------+------------------+-------+
#
# Batch ID: 8
# +-----------------------+------------------+-------+
# |czas                   |temperatura       |anomaly|
# +-----------------------+------------------+-------+
# |2026-04-25 14:40:04.733|26.903072253374702|NIE    |
# +-----------------------+------------------+-------+
#
# Batch ID: 9
# +-----------------------+------------------+-------+
# |czas                   |temperatura       |anomaly|
# +-----------------------+------------------+-------+
# |2026-04-25 14:40:05.733|20.465978542347308|NIE    |
# +-----------------------+------------------+-------+
#
# Batch ID: 10
# +-----------------------+-----------------+-------+
# |czas                   |temperatura      |anomaly|
# +-----------------------+-----------------+-------+
# |2026-04-25 14:40:06.733|26.12105891322792|NIE    |
# +-----------------------+-----------------+-------+

# %% [markdown]
# Okno czasowe: Tumbling Window

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import window
from pyspark.sql.functions import col, expr, window

spark = SparkSession.builder.appName("StreamingDemo").getOrCreate()
spark.sparkContext.setLogLevel("WARN")

def process_batch(df, batch_id, tstop=30):
    print(f"Batch ID: {batch_id}")
    df.show(truncate=False)
    if batch_id == tstop:
        df.stop()



df = (spark.readStream
      .format("rate")
      .option("rowsPerSecond", 1)
      .load()
)

stream = (df.withColumn("czas", col("timestamp"))
        .withColumn("temperatura", expr("20 + rand() * 10"))
        .select("czas", "temperatura")
       )
# Konwertuj 'temperatura' na typ Double, aby agregacja była możliwa
stream = stream.withColumn("temperatura", col("temperatura").cast("double"))

tumbling_window = (stream
    .groupBy(window(col("czas"), "10 seconds"))
    .avg("temperatura")
)

query = (tumbling_window.writeStream 
    .format("console") 
    .outputMode("complete")
    .foreachBatch(process_batch)
    .option("truncate", False) 
    .start()
)
# Out:
# Batch ID: 0
# +------+----------------+
# |window|avg(temperatura)|
# +------+----------------+
# +------+----------------+
#
# Batch ID: 1
# +------------------------------------------+------------------+
# |window                                    |avg(temperatura)  |
# +------------------------------------------+------------------+
# |{2026-04-25 14:54:10, 2026-04-25 14:54:20}|24.236516144030702|
# +------------------------------------------+------------------+
#
# Batch ID: 2
# +------------------------------------------+------------------+
# |window                                    |avg(temperatura)  |
# +------------------------------------------+------------------+
# |{2026-04-25 14:54:20, 2026-04-25 14:54:30}|25.213094466352434|
# |{2026-04-25 14:54:10, 2026-04-25 14:54:20}|24.236516144030702|
# +------------------------------------------+------------------+
#
# Batch ID: 3
# +------------------------------------------+------------------+
# |window                                    |avg(temperatura)  |
# +------------------------------------------+------------------+
# |{2026-04-25 14:54:20, 2026-04-25 14:54:30}|26.121319039332338|
# |{2026-04-25 14:54:10, 2026-04-25 14:54:20}|24.236516144030702|
# +------------------------------------------+------------------+
#
# Batch ID: 4
# +------------------------------------------+------------------+
# |window                                    |avg(temperatura)  |
# +------------------------------------------+------------------+
# |{2026-04-25 14:54:20, 2026-04-25 14:54:30}|26.443146895785855|
# |{2026-04-25 14:54:10, 2026-04-25 14:54:20}|24.236516144030702|
# +------------------------------------------+------------------+
#
# Batch ID: 5
# +------------------------------------------+------------------+
# |window                                    |avg(temperatura)  |
# +------------------------------------------+------------------+
# |{2026-04-25 14:54:20, 2026-04-25 14:54:30}|26.443146895785855|
# |{2026-04-25 14:54:30, 2026-04-25 14:54:40}|26.84997726368545 |
# |{2026-04-25 14:54:10, 2026-04-25 14:54:20}|24.236516144030702|
# +------------------------------------------+------------------+
#
# Batch ID: 6
# +------------------------------------------+------------------+
# |window                                    |avg(temperatura)  |
# +------------------------------------------+------------------+
# |{2026-04-25 14:54:20, 2026-04-25 14:54:30}|26.443146895785855|
# |{2026-04-25 14:54:30, 2026-04-25 14:54:40}|25.209358030297427|
# |{2026-04-25 14:54:10, 2026-04-25 14:54:20}|24.236516144030702|
# +------------------------------------------+------------------+
#
# Batch ID: 7
# +------------------------------------------+------------------+
# |window                                    |avg(temperatura)  |
# +------------------------------------------+------------------+
# |{2026-04-25 14:54:20, 2026-04-25 14:54:30}|26.443146895785855|
# |{2026-04-25 14:54:30, 2026-04-25 14:54:40}|24.385671804539054|
# |{2026-04-25 14:54:10, 2026-04-25 14:54:20}|24.236516144030702|
# +------------------------------------------+------------------+
#
# Batch ID: 8
# +------------------------------------------+------------------+
# |window                                    |avg(temperatura)  |
# +------------------------------------------+------------------+
# |{2026-04-25 14:54:20, 2026-04-25 14:54:30}|26.443146895785855|
# |{2026-04-25 14:54:40, 2026-04-25 14:54:50}|24.43078851254623 |
# |{2026-04-25 14:54:30, 2026-04-25 14:54:40}|24.231824283066217|
# |{2026-04-25 14:54:10, 2026-04-25 14:54:20}|24.236516144030702|
# +------------------------------------------+------------------+
#
# Batch ID: 9
# +------------------------------------------+------------------+
# |window                                    |avg(temperatura)  |
# +------------------------------------------+------------------+
# |{2026-04-25 14:54:20, 2026-04-25 14:54:30}|26.443146895785855|
# |{2026-04-25 14:54:40, 2026-04-25 14:54:50}|24.787511105295124|
# |{2026-04-25 14:54:30, 2026-04-25 14:54:40}|24.231824283066217|
# |{2026-04-25 14:54:10, 2026-04-25 14:54:20}|24.236516144030702|
# +------------------------------------------+------------------+
#
# Batch ID: 10

# %% [markdown]
# Okno czasowe: Sliding Window

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import window
from pyspark.sql.functions import col, expr, window
 
spark = SparkSession.builder.appName("StreamingDemo").getOrCreate()
spark.sparkContext.setLogLevel("WARN")

def process_batch(df, batch_id, tstop=30):
    print(f"Batch ID: {batch_id}")
    df.show(truncate=False)
    if batch_id == tstop:
        df.stop()



df = (spark.readStream
      .format("rate")
      .option("rowsPerSecond", 1)
      .load()
)

stream = (df.withColumn("czas", col("timestamp"))
        .withColumn("temperatura", expr("20 + rand() * 10"))
        .select("czas", "temperatura")
       )
# Konwertuj 'temperatura' na typ Double, aby agregacja była możliwa
stream = stream.withColumn("temperatura", col("temperatura").cast("double"))


sliding = (stream.groupBy(window(col("czas"), "10 seconds", "5 seconds"))
           .avg("temperatura")
          )

query = (sliding.writeStream 
    .format("console") 
    .outputMode("complete")
    .foreachBatch(process_batch)
    .option("truncate", False) 
    .start()
)
# Out:
# Batch ID: 0
# +------+----------------+
# |window|avg(temperatura)|
# +------+----------------+
# +------+----------------+
#
# Batch ID: 1
# +------------------------------------------+-----------------+
# |window                                    |avg(temperatura) |
# +------------------------------------------+-----------------+
# |{2026-04-25 14:55:30, 2026-04-25 14:55:40}|26.29775358236
# |{2026-04-25 14:55:30, 2026-04-25 14:55:40}|26.29775358236994 |
# |{2026-04-25 14:56:50, 2026-04-25 14:57:00}|26.520827848744737|
# |{2026-04-25 14:56:15, 2026-04-25 14:56:25}|26.78686649489432 |
# |{2026-04-25 14:56:10, 2026-04-25 14:56:20}|26.487293867236183|
# |{2026-04-25 14:56:40, 2026-04-25 14:56:50}|23.670607654677962|
# |{2026-04-25 14:55:40, 2026-04-25 14:55:50}|24.625191331687024|
# |{2026-04-25 14:56:25, 2026-04-25 14:56:35}|25.342873008467414|
# |{2026-04-25 14:57:00, 2026-04-25 14:57:10}|24.558841145716592|
# |{2026-04-25 14:56:05, 2026-04-25 14:56:15}|25.90344953413067 |
# |{2026-04-25 14:55:25, 2026-04-25 14:55:35}|28.46856493474975 |
# |{2026-04-25 14:55:50, 2026-04-25 14:56:00}|23.91916904955601 |
# |{2026-04-25 14:56:45, 2026-04-25 14:56:55}|26.113950094355324|
# |{2026-04-25 14:55:35, 2026-04-25 14:55:45}|25.527770297911506|
# |{2026-04-25 14:55:55, 2026-04-25 14:56:05}|24.842447004442942|
# +------------------------------------------+------------------+
#
# Batch ID: 30
# +------------------------------------------+------------------+
# |window                                    |avg(temperatura)  |
# +------------------------------------------+------------------+
# |{2026-04-25 14:56:00, 2026-04-25 14:56:10}|26.098200719062504|
# |{2026-04-25 14:56:30, 2026-04-25 14:56:40}|25.476863929869275|
# |{2026-04-25 14:55:45, 2026-04-25 14:55:55}|23.45288784676906 |
# |{2026-04-25 14:56:35, 2026-04-25 14:56:45}|23.779301562039233|
# |{2026-04-25 14:56:20, 2026-04-25 14:56:30}|24.702612338158843|
# |{2026-04-25 14:56:55, 2026-04-25 14:57:05}|25.86736314953192 |
# |{2026-04-25 14:55:30, 2026-04-25 14:55:40}|26.29775358236994 |
# |{2026-04-25 14:56:50, 2026-04-25 14:57:00}|26.520827848744737|
# |{2026-04-25 14:56:15, 2026-04-25 14:56:25}|26.78686649489432 |
# |{2026-04-25 14:56:10, 2026-04-25 14:56:20}|26.487293867236183|
# |{2026-04-25 14:56:40, 2026-04-25 14:56:50}|23.670607654677962|
# |{2026-04-25 14:55:40, 2026-04-25 14:55:50}|24.625191331687024|
# |{2026-04-25 14:56:25, 2026-04-25 14:56:35}|25.342873008467414|
# |{2026-04-25 14:57:00, 2026-04-25 14:57:10}|26.36869319520569 |
# |{2026-04-25 14:56:05, 2026-04-25 14:56:15}|25.90344953413067 |
# |{2026-04-25 14:55:25, 2026-04-25 14:55:35}|28.46856493474975 |
# |{2026-04-25 14:55:50, 2026-04-25 14:56:00}|23.91916904955601 |
# |{2026-04-25 14:56:45, 2026-04-25 14:56:55}|26.113950094355324|
# |{2026-04-25 14:55:35, 2026-04-25 14:55:45}|25.527770297911506|
# |{2026-04-25 14:55:55, 2026-04-25 14:56:05}|24.842447004442942|
# +------------------------------------------+------------------+

# %% [markdown]
#  Źródło plikowe (JSON)

# %%
# %%file generator.py
# generator.py
import json, os, random, time
from datetime import datetime, timedelta

output_dir = "data/stream"
os.makedirs(output_dir, exist_ok=True)

sklepy = ['Warszawa', 'Kraków', 'Gdańsk', 'Wrocław']
kategorie = ['elektronika', 'odzież', 'żywność', 'książki']

def generate_transaction():
    return {
        'tx_id': f'TX{random.randint(1000,9999)}',
        'user_id': f'u{random.randint(1,20):02d}',
        'amount': round(random.uniform(5.0, 5000.0), 2),
        'store': random.choice(sklepy),
        'category': random.choice(kategorie),
        'timestamp': datetime.now().isoformat(),
    }

# Simulate file-based streaming
while True:
    batch = [generate_transaction() for _ in range(2)]
    filename = f"{output_dir}/events_{int(time.time())}.json"
    with open(filename, "w") as f:
        for e in batch:
            f.write(json.dumps(e) + "\n")
    print(f"Wrote: {filename}")
    time.sleep(5)
# Out:
# Writing generator.py

# %%
from pyspark.sql.types import StructType, StructField, StringType, DoubleType
from pyspark.sql.functions import from_json, to_timestamp
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("jsonDemo").getOrCreate()
spark.sparkContext.setLogLevel("WARN")

tx_schema = StructType([
    StructField("tx_id",     StringType()),
    StructField("user_id",   StringType()),
    StructField("amount",    DoubleType()),
    StructField("store",     StringType()),
    StructField("category",  StringType()),
    StructField("timestamp", StringType()),
])

batch_counter = {"count": 0}

def process_batch(df, batch_id, tstop=5):
    batch_counter["count"] += 1
    print(f"Batch ID: {batch_id}")
    df.show(truncate=False)
    if batch_id == tstop:
        df.stop()
    


stream = (spark.readStream
          .schema(tx_schema)
          .json("data/stream"))

query = (stream.writeStream
         .format("console")
         .foreachBatch(process_batch)
         .start())
# Out:
# Batch ID: 0
# +------+-------+-------+--------+-----------+--------------------------+
# |tx_id |user_id|amount |store   |category   |timestamp                 |
# +------+-------+-------+--------+-----------+--------------------------+
# |TX5833|u02    |1568.61|Gdańsk  |elektronika|2026-04-25T15:07:03.916471|
# |TX7560|u11    |901.9  |Wrocław |książki    |2026-04-25T15:07:03.916512|
# |TX8022|u12    |3531.48|Gdańsk  |odzież     |2026-04-25T15:07:08.919457|
# |TX9478|u01    |4379.6 |Warszawa|elektronika|2026-04-25T15:07:08.919478|
# +------+-------+-------+--------+-----------+--------------------------+
#
# Batch ID: 1
# +------+-------+-------+--------+--------+--------------------------+
# |tx_id |user_id|amount |store   |category|timestamp                 |
# +------+-------+-------+--------+--------+--------------------------+
# |TX3596|u04    |1033.65|Kraków  |odzież  |2026-04-25T15:07:13.921680|
# |TX9201|u01    |2362.95|Warszawa|odzież  |2026-04-25T15:07:13.921696|
# +------+-------+-------+--------+--------+--------------------------+
#
# Batch ID: 2
# +------+-------+-------+-------+-----------+--------------------------+
# |tx_id |user_id|amount |store  |category   |timestamp                 |
# +------+-------+-------+-------+-----------+--------------------------+
# |TX4829|u08    |805.85 |Gdańsk |elektronika|2026-04-25T15:07:18.925840|
# |TX8494|u01    |3894.96|Wrocław|książki    |2026-04-25T15:07:18.925895|
# +------+-------+-------+-------+-----------+--------------------------+
#
# Batch ID: 3
# +------+-------+-------+-------+-----------+--------------------------+
# |tx_id |user_id|amount |store  |category   |timestamp                 |
# +------+-------+-------+-------+-----------+--------------------------+
# |TX5923|u19    |3319.11|Gdańsk |elektronika|2026-04-25T15:07:23.928522|
# |TX2615|u04    |4167.24|Wrocław|odzież     |2026-04-25T15:07:23.928537|
# +------+-------+-------+-------+-----------+--------------------------+
